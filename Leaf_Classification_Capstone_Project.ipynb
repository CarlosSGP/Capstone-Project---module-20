# %% [markdown]
# # Plant Classification Capstone Project
#
# ----
# This project aims to categorize 99 plant species using leaf characteristics: shape, margin, and texture. Various machine learning algorithms are employed and evaluated, including Naive Bayes, SVM, Logistic Regression, k-NN, and Decision Trees. Data preprocessing involves standard scaling, while cross-validation enhances model performance. Optimal parameters are determined through grid search.
#
#
# ## 1. Introduction:
#
# The objective of this project is to develop a machine learning algorithm that is able to accurately identify a plant species based on data extracted from processed images.

# %% [markdown]
# ## 2. Datasets:
# The dataset consists approximately 1,584 images of leaf specimens (16 samples each of 99 species in total, 10 samples each of 99 species are labeled, the other 6 samples are used to evaluate the model via Kaggle) which have been converted to binary black leaves against white backgrounds. Three sets of features are also provided per image: a shape contiguous descriptor, an interior texture histogram, and a ﬁne-scale margin histogram. For each feature, a 64-attribute vector is given per leaf sample.

# %% [markdown]
# **Let's have a look at the given datasets:**

# %%
# Importing some useful/necessary packages
import numpy as np
import pandas as pd
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt

from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import KFold, cross_val_score, GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, log_loss, precision_score, recall_score
from sklearn.preprocessing import MultiLabelBinarizer

from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier

# %%
# Read the .csv files as pandas dataframe
df = pd.read_csv('train.csv')
df = df.drop('id', axis=1)
#print type(train_raw), type(test_raw)
print ('There are {}'.format(df.shape[0]), \
       'samples for building the machine learning model and {}'.format(df.shape[0]), \
       'samples for evaluating your model')
# Out:
# There are 990 samples for building the machine learning model and 990 samples for evaluating your model

# %%
# Let's look at the first 5 rows of train_raw dataset
df.head(5)
# Out:
#                  species   margin1   margin2   margin3   margin4   margin5  \
# 0            Acer_Opalus  0.007812  0.023438  0.023438  0.003906  0.011719
# 1  Pterocarya_Stenoptera  0.005859  0.000000  0.031250  0.015625  0.025391
# 2   Quercus_Hartwissiana  0.005859  0.009766  0.019531  0.007812  0.003906
# 3        Tilia_Tomentosa  0.000000  0.003906  0.023438  0.005859  0.021484
# 4     Quercus_Variabilis  0.005859  0.003906  0.048828  0.009766  0.013672
#
#     margin6   margin7  margin8   margin9  ...  texture55  texture56  \
# 0  0.009766  0.027344      0.0  0.001953  ...   0.007812   0.000000
# 1  0.001953  0.019531      0.0  0.000000  ...   0.000977   0.000000
# 2  0.005859  0.068359      0.0  0.000000  ...   0.154300   0.000000
# 3  0.019531  0.023438      0.0  0.013672  ...   0.000000   0.000977
# 4  0.015625  0.005859      0.0  0.000000  ...   0.096680   0.000000
#
#    texture57  texture58  texture59  texture60  texture61  texture62  \
# 0   0.002930   0.002930   0.035156        0.0        0.0   0.004883
# 1   0.000000   0.000977   0.023438        0.0        0.0   0.000977
# 2   0.005859   0.000977   0.007812        0.0        0.0   0.000000
# 3   0.000000   0.000000   0.020508        0.0        0.0   0.017578
# 4   0.021484   0.000000   0.000000        0.0        0.0   0.000000
#
#    texture63  texture64
# 0   0.000000   0.025391
# 1   0.039062   0.022461
# 2   0.020508   0.002930
# 3   0.000000   0.047852
# 4   0.000000   0.031250
#
# [5 rows x 193 columns]

# %%
# Let's review if there are any null values in the data
df.isnull().sum()
# Out:
# species      0
# margin1      0
# margin2      0
# margin3      0
# margin4      0
#             ..
# texture60    0
# texture61    0
# texture62    0
# texture63    0
# texture64    0
# Length: 193, dtype: int64

# %%
# Checking balance on train set
df['species'].value_counts(normalize = True)
# Out:
# species
# Acer_Opalus                    0.010101
# Crataegus_Monogyna             0.010101
# Acer_Mono                      0.010101
# Magnolia_Heptapeta             0.010101
# Acer_Capillipes                0.010101
#                                  ...
# Alnus_Rubra                    0.010101
# Rhododendron_x_Russellianum    0.010101
# Cytisus_Battandieri            0.010101
# Liriodendron_Tulipifera        0.010101
# Sorbus_Aria                    0.010101
# Name: proportion, Length: 99, dtype: float64

# %% [markdown]
# **df** dataset has the shape of [990x194]. 990 represents the number of species, and 194 represents individual features in columns i.e. 'id', 'species', 'margin1-64', 'shape1-64', 'texture1-64'.
#
# More in detail for 194:
# - id - an anonymous id unique to an image
# - species - 99 species, not given in test.csv
# - margin_1, margin_2, margin_3, ..., margin_64 - each of the 64 attribute vectors for the margin feature
# - shape_1, shape_2, shape_3, ..., shape_64 - each of the 64 attribute vectors for the shape feature
# - texture_1, texture_2, texture_3, ..., texture_64 - each of the 64 attribute vectors for the texture feature

# %% [markdown]
# ## 3. Methods
#
# To make life easier, *Python* and *Scikit-learn* were depolyed in this project.
#
#
# **Cross-validation**
#
# To improve our model's effectiveness, we'll employ cross-validation. This technique involves repeatedly dividing the data and training several models.
#
# **Grid Search**
#
# Grid search is the most widely utilized approach for determining optimal model parameters. It essentially involves testing all potential combinations of the parameters under consideration.
#
#
# We will follow these steps in our project:
#
# 1. Preprocess the data
#     - Split data for training and testing
#     - Split for cross-validation
#     - Standard-scaler
# - Feed the preprocessed data into the selected classifiers
#     1. Naive Bayes
#     - Support Vector Machine (SVM)
#     - Logistic Regression
#     - k-nearest neighbours (k-NN)
#     - Random Forest
# - Evaluate the classifiers
#
# **Evaluation Metrics**
#
# We will evaluate each model based on it's accuracy rate and the minimization of the log loss function.

# %% [markdown]
# ## 4. Implementation
#
# ### 4.1 Data preprocessing for classifiers
#
# To organize the data, scikit learn provides [LabelEncoder](http://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.LabelEncoder.html).

# %%
# Split data into training and test sets
train_data, test_data = train_test_split(df, test_size=0.3, random_state=42)

# Split training set into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(train_data.drop('species', axis=1), train_data.species, 
                                                  test_size=0.3, random_state=42, stratify=train_data.species)
# Fit LabelEncoder to the training set and transform both the training and validation set labels
le = LabelEncoder()
y_train_encoded = le.fit_transform(y_train)
y_val_encoded = le.transform(y_val)

# %% [markdown]
# #### Split the 'train' data for cross-validation
# KFold cross validation iterator is used to split the training dataset.

# %%
# Define the iterator
kf_split = KFold(n_splits=10, shuffle=True, random_state=42)

for fold, (train_index, test_index) in enumerate(kf_split.split(df)):
    # Split the data into training and test sets
    train_data = df.iloc[train_index]
    test_data = df.iloc[test_index]

# %%
print(X_train.shape)
print(y_train.shape)
print(X_val.shape)
print(y_val.shape)
# Out:
# (485, 192)
# (485,)
# (208, 192)
# (208,)

# %%
# Check the encoding of the target variable
print("Unique values in y_train_encoded:", len(set(y_train_encoded)))
print("y_train_encoded value counts:\n", pd.Series(y_train_encoded).value_counts())

print("Unique values in y_val_encoded:", len(set(y_val_encoded)))
print("y_val_encoded value counts:\n", pd.Series(y_val_encoded).value_counts())
# Out:
# Unique values in y_train_encoded: 99
# y_train_encoded value counts:
#  77    7
# 87    7
# 84    7
# 96    6
# 38    6
#      ..
# 10    3
# 33    3
# 27    3
# 83    3
# 89    3
# Name: count, Length: 99, dtype: int64
# Unique values in y_val_encoded: 99
# y_val_encoded value counts:
#  90    3
# 42    3
# 84    3
# 22    3
# 38    3
#      ..
# 35    1
# 9     1
# 40    1
# 66    1
# 17    1
# Name: count, Length: 99, dtype: int64

# %% [markdown]
# Now we have split the 'train' dataset into two parts:
# - X_train, y_train
# - X_val, y_val

# %% [markdown]
# ### 4.2 Machine learning classifiers
#
# The following listed classifiers are selected in this project as their popularity.
# 1. Naive Bayes
# - SVM
# - Logistic Regression
# - k-nearest neighbours (k-NN)
# - LinearDiscriminantAnalysis

# %% [markdown]
# #### 4.2.1 Naive Bayes

# %%
clf = GaussianNB().fit(X_train, y_train)
print('ML Model:', clf.__class__.__name__)

# Cross-validation
scores = cross_val_score(GaussianNB(), X_train.values, y_train, cv=kf_split)

train_predictions = clf.predict(X_val)

#Accuracy
acc = accuracy_score(y_val, train_predictions)
print ('Accuracy: {:.4%}'.format(acc))

#Precision
precision = precision_score(y_val, train_predictions, average='weighted')
print('Precision: {:.4%}'.format(precision))

#Recall
recall = recall_score(y_val, train_predictions,average='weighted')
print('Recall: {:.4%}'.format(recall))

#Log loss
train_predictions = clf.predict_proba(X_val)
ll = log_loss(y_val, train_predictions)
print ('Log Loss: {:.6}'.format(ll))
# Out:
# ML Model: GaussianNB
# Accuracy: 35.5769%
# Precision: 37.9317%
# Recall: 35.5769%
# Log Loss: 23.0879
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# #### 4.2.2 Support Vector Machine

# %%
clf = SVC(probability=True)

# Grid search
#param_grid = {'C': [1, 10, 100, 1000, 10000, 100000],
#              'gamma': [1, 10, 100, 1000, 10000, 100000]}
param_grid = {'C': [0.001, 0.01, 0.1, 1, 10, 100],
              'gamma': [0.001, 0.01, 0.1, 1, 10, 100]}

grid_search = GridSearchCV(SVC(probability=True), param_grid=param_grid, cv=kf_split)
grid_search.fit(X_train, y_train)

print ('Best parameter: {}'.format(grid_search.best_params_))
print ('Best cross-validation accuracy score: {}'.format(grid_search.best_score_))
print ('\nBest estimator:\n{}'.format(grid_search.best_estimator_))
# Out:
# Best parameter: {'C': 100, 'gamma': 1}
# Best cross-validation accuracy score: 0.8372448979591838
#
# Best estimator:
# SVC(C=100, gamma=1, probability=True)

# %%
# Accuracy
train_predictions = grid_search.predict(X_val)
acc = accuracy_score(y_val, train_predictions)
print ('Accuracy: {:.4%}'.format(acc))

#Precision
precision = precision_score(y_val, train_predictions, average='weighted')
print('Precision: {:.4%}'.format(precision))

#Recall
recall = recall_score(y_val, train_predictions,average='weighted')
print('Recall: {:.4%}'.format(recall))


# Logloss
train_predictions = grid_search.predict_proba(X_val)
ll = log_loss(y_val, train_predictions)
print ('Log Loss: {:.6}'.format(ll))
# Out:
# Accuracy: 89.9038%
# Precision: 90.2244%
# Recall: 89.9038%
# Log Loss: 2.75609
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# #### 4.2.3 Logistic Regression

# %%
# Standardize the training data.
scaler = StandardScaler().fit(X_train)
X_train_scaled = scaler.transform(X_train)

#param_grid = {'C':[1, 10], 
#              'tol': [0.001, 0.0001]}
param_grid = {'C': [1, 10, 100],
              'tol': [0.001, 0.01, 0.1]}
log_reg = LogisticRegression(max_iter=10000, multi_class='multinomial', random_state=42)
grid_search = GridSearchCV(log_reg, param_grid, scoring='neg_log_loss', refit='True', n_jobs=1, cv=kf_split)
grid_search.fit(X_train_scaled, y_train)

print ('Best parameter: {}'.format(grid_search.best_params_))
print ('Best cross-validation neg_log_loss score: {}'.format(grid_search.best_score_))
print ('\nBest estimator:\n{}'.format(grid_search.best_estimator_))
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 327, in _score
#     return self._sign * self._score_func(y, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 2635, in log_loss
#     raise ValueError(
# ValueError: y_true and y_pred contain different number of classes 37, 99. Please provide the true labels explicitly through the labels argument. Classes found in y_true: ['Acer_Pictum' 'Acer_Platanoids' 'Acer_Rubrum' 'Acer_Saccharinum'
#  'Alnus_Viridis' 'Betula_Austrosinensis' 'Celtis_Koraiensis'
#  'Cytisus_Battandieri' 'Eucalyptus_Neglecta' 'Fagus_Sylvatica'
#  'Ginkgo_Biloba' 'Ilex_Cornuta' 'Magnolia_Heptapeta'
#  'Magnolia_Salicifolia' 'Olea_Europaea' 'Populus_Grandidentata'
#  'Pterocarya_Stenoptera' 'Quercus_Agrifolia' 'Quercus_Brantii'
#  'Quercus_Castaneifolia' 'Quercus_Cerris' 'Quercus_Coccifera'
#  'Quercus_Crassifolia' 'Quercus_Dolicholepis' 'Quercus_Ilex'
#  'Quercus_Infectoria_sub' 'Quercus_Phellos' 'Quercus_Phillyraeoides'
#  'Quercus_Pontica' 'Quercus_Rubra' 'Quercus_Semecarpifolia'
#  'Quercus_Shumardii' 'Quercus_Suber' 'Quercus_x_Hispanica'
#  'Salix_Intergra' 'Ulmus_Bergmanniana' 'Zelkova_Serrata']
#
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 327, in _score
#     return self._sign * self._score_func(y, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 2635, in log_loss
#     raise ValueError(
# ValueError: y_true and y_pred contain different number of classes 37, 99. Please provide the true labels explicitly through the labels argument. Classes found in y_true: ['Acer_Circinatum' 'Acer_Mono' 'Acer_Opalus' 'Acer_Platanoids'
#  'Acer_Rubrum' 'Acer_Rufinerve' 'Alnus_Maximowiczii' 'Alnus_Viridis'
#  'Callicarpa_Bodinieri' 'Cercis_Siliquastrum' 'Cornus_Chinensis'
#  'Cornus_Controversa' 'Cornus_Macrophylla' 'Crataegus_Monogyna'
#  'Liriodendron_Tulipifera' 'Lithocarpus_Cleistocarpus'
#  'Lithocarpus_Edulis' 'Morus_Nigra' 'Populus_Adenopoda'
#  'Populus_Grandidentata' 'Prunus_Avium' 'Pterocarya_Stenoptera'
#  'Quercus_Afares' 'Quercus_Brantii' 'Quercus_Cerris' 'Quercus_Coccifera'
#  'Quercus_Coccinea' 'Quercus_Dolicholepis' 'Quercus_Greggii'
#  'Quercus_Infectoria_sub' 'Quercus_Palustris' 'Quercus_Pubescens'
#  'Quercus_Pyrenaica' 'Quercus_Suber' 'Quercus_Vulcanica'
#  'Quercus_x_Turneri' 'Rhododendron_x_Russellianum']
#
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 327, in _score
#     return self._sign * self._score_func(y, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 2635, in log_loss
#     raise ValueError(
# ValueError: y_true and y_pred contain different number of classes 41, 99. Please provide the true labels explicitly through the labels argument. Classes found in y_true: ['Acer_Capillipes' 'Acer_Palmatum' 'Acer_Rubrum' 'Alnus_Maximowiczii'
#  'Alnus_Rubra' 'Alnus_Viridis' 'Arundinaria_Simonii' 'Betula_Pendula'
#  'Callicarpa_Bodinieri' 'Cornus_Chinensis' 'Cornus_Controversa'
#  'Cotinus_Coggygria' 'Crataegus_Monogyna' 'Cytisus_Battandieri'
#  'Ginkgo_Biloba' 'Lithocarpus_Cleistocarpus' 'Lithocarpus_Edulis'
#  'Magnolia_Heptapeta' 'Magnolia_Salicifolia' 'Olea_Europaea'
#  'Populus_Adenopoda' 'Populus_Nigra' 'Quercus_Agrifolia'
#  'Quercus_Canariensis' 'Quercus_Castaneifolia' 'Quercus_Chrysolepis'
#  'Quercus_Coccinea' 'Quercus_Crassipes' 'Quercus_Ellipsoidalis'
#  'Quercus_Hartwissiana' 'Quercus_Infectoria_sub' 'Quercus_Pubescens'
#  'Quercus_Rhysophylla' 'Quercus_Rubra' 'Quercus_Shumardii'
#  'Quercus_Trojana' 'Quercus_Variabilis' 'Quercus_x_Turneri'
#  'Salix_Fragilis' 'Sorbus_Aria' 'Tilia_Platyphyllos']
#
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 327, in _score
#     return self._sign * self._score_func(y, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 2635, in log_loss
#     raise ValueError(
# ValueError: y_true and y_pred contain different number of classes 39, 99. Please provide the true labels explicitly through the labels argument. Classes found in y_true: ['Acer_Capillipes' 'Acer_Circinatum' 'Acer_Opalus' 'Acer_Palmatum'
#  'Acer_Platanoids' 'Alnus_Rubra' 'Alnus_Sieboldiana' 'Alnus_Viridis'
#  'Arundinaria_Simonii' 'Betula_Austrosinensis' 'Betula_Pendula'
#  'Castanea_Sativa' 'Cercis_Siliquastrum' 'Cotinus_Coggygria'
#  'Eucalyptus_Glaucescens' 'Eucalyptus_Urnigera' 'Fagus_Sylvatica'
#  'Lithocarpus_Edulis' 'Prunus_X_Shmittii' 'Quercus_Afares'
#  'Quercus_Chrysolepis' 'Quercus_Crassifolia' 'Quercus_Dolicholepis'
#  'Quercus_Greggii' 'Quercus_Hartwissiana' 'Quercus_Palustris'
#  'Quercus_Phellos' 'Quercus_Rhysophylla' 'Quercus_Rubra'
#  'Quercus_Semecarpifolia' 'Quercus_Suber' 'Quercus_Variabilis'
#  'Quercus_x_Hispanica' 'Sorbus_Aria' 'Tilia_Oliveri' 'Tilia_Platyphyllos'
#  'Tilia_Tomentosa' 'Ulmus_Bergmanniana' 'Viburnum_x_Rhytidophylloides']
#
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 327, in _score
#     return self._sign * self._score_func(y, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 2635, in log_loss
#     raise ValueError(
# ValueError: y_true and y_pred contain different number of classes 43, 99. Please provide the true labels explicitly through the labels argument. Classes found in y_true: ['Acer_Circinatum' 'Acer_Mono' 'Acer_Rufinerve' 'Acer_Saccharinum'
#  'Alnus_Maximowiczii' 'Alnus_Viridis' 'Castanea_Sativa'
#  'Celtis_Koraiensis' 'Cornus_Chinensis' 'Crataegus_Monogyna'
#  'Fagus_Sylvatica' 'Ilex_Cornuta' 'Olea_Europaea' 'Phildelphus'
#  'Populus_Adenopoda' 'Populus_Nigra' 'Prunus_X_Shmittii'
#  'Pterocarya_Stenoptera' 'Quercus_Agrifolia' 'Quercus_Alnifolia'
#  'Quercus_Brantii' 'Quercus_Canariensis' 'Quercus_Castaneifolia'
#  'Quercus_Chrysolepis' 'Quercus_Coccinea' 'Quercus_Crassipes'
#  'Quercus_Infectoria_sub' 'Quercus_Kewensis' 'Quercus_Nigra'
#  'Quercus_Phillyraeoides' 'Quercus_Pontica' 'Quercus_Rhysophylla'
#  'Quercus_Texana' 'Quercus_Trojana' 'Quercus_Variabilis'
#  'Quercus_Vulcanica' 'Quercus_x_Turneri' 'Rhododendron_x_Russellianum'
#  'Salix_Intergra' 'Sorbus_Aria' 'Tilia_Oliveri'
#  'Viburnum_x_Rhytidophylloides' 'Zelkova_Serrata']
#
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 327, in _score
#     return self._sign * self._score_func(y, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 2635, in log_loss
#     raise ValueError(
# ValueError: y_true and y_pred contain different number of classes 42, 99. Please provide the true labels explicitly through the labels argument. Classes found in y_true: ['Acer_Opalus' 'Acer_Palmatum' 'Acer_Pictum' 'Acer_Rubrum'
#  'Acer_Saccharinum' 'Alnus_Cordata' 'Alnus_Maximowiczii' 'Alnus_Rubra'
#  'Arundinaria_Simonii' 'Betula_Austrosinensis' 'Castanea_Sativa'
#  'Celtis_Koraiensis' 'Cornus_Controversa' 'Eucalyptus_Glaucescens'
#  'Eucalyptus_Neglecta' 'Ginkgo_Biloba' 'Ilex_Aquifolium'
#  'Liquidambar_Styraciflua' 'Liriodendron_Tulipifera'
#  'Lithocarpus_Cleistocarpus' 'Lithocarpus_Edulis' 'Magnolia_Heptapeta'
#  'Magnolia_Salicifolia' 'Morus_Nigra' 'Olea_Europaea' 'Quercus_Cerris'
#  'Quercus_Coccifera' 'Quercus_Ellipsoidalis' 'Quercus_Hartwissiana'
#  'Quercus_Infectoria_sub' 'Quercus_Pontica' 'Quercus_Pyrenaica'
#  'Quercus_Rhysophylla' 'Quercus_Suber' 'Quercus_Variabilis'
#  'Quercus_x_Turneri' 'Rhododendron_x_Russellianum' 'Salix_Fragilis'
#  'Salix_Intergra' 'Sorbus_Aria' 'Tilia_Oliveri' 'Viburnum_Tinus']
#
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 327, in _score
#     return self._sign * self._score_func(y, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 2635, in log_loss
#     raise ValueError(
# ValueError: y_true and y_pred contain different number of classes 36, 99. Please provide the true labels explicitly through the labels argument. Classes found in y_true: ['Acer_Circinatum' 'Acer_Palmatum' 'Acer_Rufinerve' 'Alnus_Maximowiczii'
#  'Betula_Pendula' 'Callicarpa_Bodinieri' 'Celtis_Koraiensis'
#  'Cornus_Macrophylla' 'Cotinus_Coggygria' 'Cytisus_Battandieri'
#  'Eucalyptus_Neglecta' 'Eucalyptus_Urnigera' 'Ilex_Aquifolium'
#  'Magnolia_Heptapeta' 'Olea_Europaea' 'Populus_Nigra'
#  'Pterocarya_Stenoptera' 'Quercus_Agrifolia' 'Quercus_Canariensis'
#  'Quercus_Cerris' 'Quercus_Coccifera' 'Quercus_Crassifolia'
#  'Quercus_Crassipes' 'Quercus_Ilex' 'Quercus_Imbricaria'
#  'Quercus_Kewensis' 'Quercus_Pontica' 'Quercus_Rhysophylla'
#  'Quercus_Semecarpifolia' 'Quercus_Shumardii' 'Quercus_Texana'
#  'Quercus_Variabilis' 'Rhododendron_x_Russellianum' 'Tilia_Platyphyllos'
#  'Tilia_Tomentosa' 'Viburnum_Tinus']
#
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 327, in _score
#     return self._sign * self._score_func(y, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 2635, in log_loss
#     raise ValueError(
# ValueError: y_true and y_pred contain different number of classes 39, 99. Please provide the true labels explicitly through the labels argument. Classes found in y_true: ['Acer_Mono' 'Acer_Pictum' 'Alnus_Cordata' 'Alnus_Rubra'
#  'Alnus_Sieboldiana' 'Betula_Austrosinensis' 'Betula_Pendula'
#  'Eucalyptus_Glaucescens' 'Fagus_Sylvatica' 'Ginkgo_Biloba'
#  'Ilex_Aquifolium' 'Liquidambar_Styraciflua' 'Liriodendron_Tulipifera'
#  'Populus_Nigra' 'Prunus_Avium' 'Prunus_X_Shmittii' 'Quercus_Alnifolia'
#  'Quercus_Brantii' 'Quercus_Castaneifolia' 'Quercus_Chrysolepis'
#  'Quercus_Coccifera' 'Quercus_Crassipes' 'Quercus_Ellipsoidalis'
#  'Quercus_Imbricaria' 'Quercus_Kewensis' 'Quercus_Nigra'
#  'Quercus_Palustris' 'Quercus_Phellos' 'Quercus_Phillyraeoides'
#  'Quercus_Pontica' 'Quercus_Pubescens' 'Quercus_Pyrenaica'
#  'Quercus_Semecarpifolia' 'Quercus_Suber' 'Quercus_Texana'
#  'Quercus_x_Turneri' 'Tilia_Platyphyllos' 'Ulmus_Bergmanniana'
#  'Viburnum_Tinus']
#
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 327, in _score
#     return self._sign * self._score_func(y, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 2635, in log_loss
#     raise ValueError(
# ValueError: y_true and y_pred contain different number of classes 41, 99. Please provide the true labels explicitly through the labels argument. Classes found in y_true: ['Acer_Mono' 'Acer_Opalus' 'Acer_Pictum' 'Acer_Rubrum' 'Acer_Rufinerve'
#  'Alnus_Cordata' 'Alnus_Rubra' 'Alnus_Sieboldiana' 'Arundinaria_Simonii'
#  'Betula_Austrosinensis' 'Castanea_Sativa' 'Cornus_Controversa'
#  'Cornus_Macrophylla' 'Cotinus_Coggygria' 'Eucalyptus_Urnigera'
#  'Lithocarpus_Edulis' 'Phildelphus' 'Populus_Nigra' 'Prunus_Avium'
#  'Prunus_X_Shmittii' 'Quercus_Afares' 'Quercus_Alnifolia'
#  'Quercus_Canariensis' 'Quercus_Cerris' 'Quercus_Coccifera'
#  'Quercus_Coccinea' 'Quercus_Dolicholepis' 'Quercus_Kewensis'
#  'Quercus_Nigra' 'Quercus_Palustris' 'Quercus_Phellos' 'Quercus_Pubescens'
#  'Quercus_Pyrenaica' 'Quercus_Rubra' 'Quercus_Suber' 'Quercus_Trojana'
#  'Quercus_x_Hispanica' 'Salix_Fragilis' 'Salix_Intergra' 'Tilia_Oliveri'
#  'Viburnum_x_Rhytidophylloides']
#
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 327, in _score
#     return self._sign * self._score_func(y, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 2635, in log_loss
#     raise ValueError(
# ValueError: y_true and y_pred contain different number of classes 41, 99. Please provide the true labels explicitly through the labels argument. Classes found in y_true: ['Acer_Capillipes' 'Acer_Circinatum' 'Acer_Opalus' 'Acer_Palmatum'
#  'Acer_Rufinerve' 'Alnus_Rubra' 'Alnus_Sieboldiana' 'Callicarpa_Bodinieri'
#  'Castanea_Sativa' 'Cercis_Siliquastrum' 'Cornus_Chinensis'
#  'Cornus_Macrophylla' 'Eucalyptus_Urnigera' 'Fagus_Sylvatica'
#  'Liquidambar_Styraciflua' 'Lithocarpus_Cleistocarpus'
#  'Lithocarpus_Edulis' 'Magnolia_Heptapeta' 'Morus_Nigra' 'Phildelphus'
#  'Quercus_Afares' 'Quercus_Chrysolepis' 'Quercus_Crassipes'
#  'Quercus_Ellipsoidalis' 'Quercus_Greggii' 'Quercus_Hartwissiana'
#  'Quercus_Ilex' 'Quercus_Kewensis' 'Quercus_Nigra' 'Quercus_Rhysophylla'
#  'Quercus_Semecarpifolia' 'Quercus_Texana' 'Quercus_Vulcanica'
#  'Rhododendron_x_Russellianum' 'Sorbus_Aria' 'Tilia_Oliveri'
#  'Tilia_Platyphyllos' 'Tilia_Tomentosa' 'Ulmus_Bergmanniana'
#  'Viburnum_Tinus' 'Zelkova_Serrata']
#
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 327, in _score
#     return self._sign * self._score_func(y, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 2635, in log_loss
#     raise ValueError(
# ValueError: y_true and y_pred contain different number of classes 37, 99. Please provide the true labels explicitly through the labels argument. Classes found in y_true: ['Acer_Pictum' 'Acer_Platanoids' 'Acer_Rubrum' 'Acer_Saccharinum'
#  'Alnus_Viridis' 'Betula_Austrosinensis' 'Celtis_Koraiensis'
#  'Cytisus_Battandieri' 'Eucalyptus_Neglecta' 'Fagus_Sylvatica'
#  'Ginkgo_Biloba' 'Ilex_Cornuta' 'Magnolia_Heptapeta'
#  'Magnolia_Salicifolia' 'Olea_Europaea' 'Populus_Grandidentata'
#  'Pterocarya_Stenoptera' 'Quercus_Agrifolia' 'Quercus_Brantii'
#  'Quercus_Castaneifolia' 'Quercus_Cerris' 'Quercus_Coccifera'
#  'Quercus_Crassifolia' 'Quercus_Dolicholepis' 'Quercus_Ilex'
#  'Quercus_Infectoria_sub' 'Quercus_Phellos' 'Quercus_Phillyraeoides'
#  'Quercus_Pontica' 'Quercus_Rubra' 'Quercus_Semecarpifolia'
#  'Quercus_Shumardii' 'Quercus_Suber' 'Quercus_x_Hispanica'
#  'Salix_Intergra' 'Ulmus_Bergmanniana' 'Zelkova_Serrata']
#
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 327, in _score
#     return self._sign * self._score_func(y, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 2635, in log_loss
#     raise ValueError(
# ValueError: y_true and y_pred contain different number of classes 37, 99. Please provide the true labels explicitly through the labels argument. Classes found in y_true: ['Acer_Circinatum' 'Acer_Mono' 'Acer_Opalus' 'Acer_Platanoids'
#  'Acer_Rubrum' 'Acer_Rufinerve' 'Alnus_Maximowiczii' 'Alnus_Viridis'
#  'Callicarpa_Bodinieri' 'Cercis_Siliquastrum' 'Cornus_Chinensis'
#  'Cornus_Controversa' 'Cornus_Macrophylla' 'Crataegus_Monogyna'
#  'Liriodendron_Tulipifera' 'Lithocarpus_Cleistocarpus'
#  'Lithocarpus_Edulis' 'Morus_Nigra' 'Populus_Adenopoda'
#  'Populus_Grandidentata' 'Prunus_Avium' 'Pterocarya_Stenoptera'
#  'Quercus_Afares' 'Quercus_Brantii' 'Quercus_Cerris' 'Quercus_Coccifera'
#  'Quercus_Coccinea' 'Quercus_Dolicholepis' 'Quercus_Greggii'
#  'Quercus_Infectoria_sub' 'Quercus_Palustris' 'Quercus_Pubescens'
#  'Quercus_Pyrenaica' 'Quercus_Suber' 'Quercus_Vulcanica'
#  'Quercus_x_Turneri' 'Rhododendron_x_Russellianum']
#
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 327, in _score
#     return self._sign * self._score_func(y, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 2635, in log_loss
#     raise ValueError(
# ValueError: y_true and y_pred contain different number of classes 41, 99. Please provide the true labels explicitly through the labels argument. Classes found in y_true: ['Acer_Capillipes' 'Acer_Palmatum' 'Acer_Rubrum' 'Alnus_Maximowiczii'
#  'Alnus_Rubra' 'Alnus_Viridis' 'Arundinaria_Simonii' 'Betula_Pendula'
#  'Callicarpa_Bodinieri' 'Cornus_Chinensis' 'Cornus_Controversa'
#  'Cotinus_Coggygria' 'Crataegus_Monogyna' 'Cytisus_Battandieri'
#  'Ginkgo_Biloba' 'Lithocarpus_Cleistocarpus' 'Lithocarpus_Edulis'
#  'Magnolia_Heptapeta' 'Magnolia_Salicifolia' 'Olea_Europaea'
#  'Populus_Adenopoda' 'Populus_Nigra' 'Quercus_Agrifolia'
#  'Quercus_Canariensis' 'Quercus_Castaneifolia' 'Quercus_Chrysolepis'
#  'Quercus_Coccinea' 'Quercus_Crassipes' 'Quercus_Ellipsoidalis'
#  'Quercus_Hartwissiana' 'Quercus_Infectoria_sub' 'Quercus_Pubescens'
#  'Quercus_Rhysophylla' 'Quercus_Rubra' 'Quercus_Shumardii'
#  'Quercus_Trojana' 'Quercus_Variabilis' 'Quercus_x_Turneri'
#  'Salix_Fragilis' 'Sorbus_Aria' 'Tilia_Platyphyllos']
#
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 327, in _score
#     return self._sign * self._score_func(y, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 2635, in log_loss
#     raise ValueError(
# ValueError: y_true and y_pred contain different number of classes 39, 99. Please provide the true labels explicitly through the labels argument. Classes found in y_true: ['Acer_Capillipes' 'Acer_Circinatum' 'Acer_Opalus' 'Acer_Palmatum'
#  'Acer_Platanoids' 'Alnus_Rubra' 'Alnus_Sieboldiana' 'Alnus_Viridis'
#  'Arundinaria_Simonii' 'Betula_Austrosinensis' 'Betula_Pendula'
#  'Castanea_Sativa' 'Cercis_Siliquastrum' 'Cotinus_Coggygria'
#  'Eucalyptus_Glaucescens' 'Eucalyptus_Urnigera' 'Fagus_Sylvatica'
#  'Lithocarpus_Edulis' 'Prunus_X_Shmittii' 'Quercus_Afares'
#  'Quercus_Chrysolepis' 'Quercus_Crassifolia' 'Quercus_Dolicholepis'
#  'Quercus_Greggii' 'Quercus_Hartwissiana' 'Quercus_Palustris'
#  'Quercus_Phellos' 'Quercus_Rhysophylla' 'Quercus_Rubra'
#  'Quercus_Semecarpifolia' 'Quercus_Suber' 'Quercus_Variabilis'
#  'Quercus_x_Hispanica' 'Sorbus_Aria' 'Tilia_Oliveri' 'Tilia_Platyphyllos'
#  'Tilia_Tomentosa' 'Ulmus_Bergmanniana' 'Viburnum_x_Rhytidophylloides']
#
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 327, in _score
#     return self._sign * self._score_func(y, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 2635, in log_loss
#     raise ValueError(
# ValueError: y_true and y_pred contain different number of classes 43, 99. Please provide the true labels explicitly through the labels argument. Classes found in y_true: ['Acer_Circinatum' 'Acer_Mono' 'Acer_Rufinerve' 'Acer_Saccharinum'
#  'Alnus_Maximowiczii' 'Alnus_Viridis' 'Castanea_Sativa'
#  'Celtis_Koraiensis' 'Cornus_Chinensis' 'Crataegus_Monogyna'
#  'Fagus_Sylvatica' 'Ilex_Cornuta' 'Olea_Europaea' 'Phildelphus'
#  'Populus_Adenopoda' 'Populus_Nigra' 'Prunus_X_Shmittii'
#  'Pterocarya_Stenoptera' 'Quercus_Agrifolia' 'Quercus_Alnifolia'
#  'Quercus_Brantii' 'Quercus_Canariensis' 'Quercus_Castaneifolia'
#  'Quercus_Chrysolepis' 'Quercus_Coccinea' 'Quercus_Crassipes'
#  'Quercus_Infectoria_sub' 'Quercus_Kewensis' 'Quercus_Nigra'
#  'Quercus_Phillyraeoides' 'Quercus_Pontica' 'Quercus_Rhysophylla'
#  'Quercus_Texana' 'Quercus_Trojana' 'Quercus_Variabilis'
#  'Quercus_Vulcanica' 'Quercus_x_Turneri' 'Rhododendron_x_Russellianum'
#  'Salix_Intergra' 'Sorbus_Aria' 'Tilia_Oliveri'
#  'Viburnum_x_Rhytidophylloides' 'Zelkova_Serrata']
#
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 327, in _score
#     return self._sign * self._score_func(y, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 2635, in log_loss
#     raise ValueError(
# ValueError: y_true and y_pred contain different number of classes 42, 99. Please provide the true labels explicitly through the labels argument. Classes found in y_true: ['Acer_Opalus' 'Acer_Palmatum' 'Acer_Pictum' 'Acer_Rubrum'
#  'Acer_Saccharinum' 'Alnus_Cordata' 'Alnus_Maximowiczii' 'Alnus_Rubra'
#  'Arundinaria_Simonii' 'Betula_Austrosinensis' 'Castanea_Sativa'
#  'Celtis_Koraiensis' 'Cornus_Controversa' 'Eucalyptus_Glaucescens'
#  'Eucalyptus_Neglecta' 'Ginkgo_Biloba' 'Ilex_Aquifolium'
#  'Liquidambar_Styraciflua' 'Liriodendron_Tulipifera'
#  'Lithocarpus_Cleistocarpus' 'Lithocarpus_Edulis' 'Magnolia_Heptapeta'
#  'Magnolia_Salicifolia' 'Morus_Nigra' 'Olea_Europaea' 'Quercus_Cerris'
#  'Quercus_Coccifera' 'Quercus_Ellipsoidalis' 'Quercus_Hartwissiana'
#  'Quercus_Infectoria_sub' 'Quercus_Pontica' 'Quercus_Pyrenaica'
#  'Quercus_Rhysophylla' 'Quercus_Suber' 'Quercus_Variabilis'
#  'Quercus_x_Turneri' 'Rhododendron_x_Russellianum' 'Salix_Fragilis'
#  'Salix_Intergra' 'Sorbus_Aria' 'Tilia_Oliveri' 'Viburnum_Tinus']
#
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 327, in _score
#     return self._sign * self._score_func(y, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 2635, in log_loss
#     raise ValueError(
# ValueError: y_true and y_pred contain different number of classes 36, 99. Please provide the true labels explicitly through the labels argument. Classes found in y_true: ['Acer_Circinatum' 'Acer_Palmatum' 'Acer_Rufinerve' 'Alnus_Maximowiczii'
#  'Betula_Pendula' 'Callicarpa_Bodinieri' 'Celtis_Koraiensis'
#  'Cornus_Macrophylla' 'Cotinus_Coggygria' 'Cytisus_Battandieri'
#  'Eucalyptus_Neglecta' 'Eucalyptus_Urnigera' 'Ilex_Aquifolium'
#  'Magnolia_Heptapeta' 'Olea_Europaea' 'Populus_Nigra'
#  'Pterocarya_Stenoptera' 'Quercus_Agrifolia' 'Quercus_Canariensis'
#  'Quercus_Cerris' 'Quercus_Coccifera' 'Quercus_Crassifolia'
#  'Quercus_Crassipes' 'Quercus_Ilex' 'Quercus_Imbricaria'
#  'Quercus_Kewensis' 'Quercus_Pontica' 'Quercus_Rhysophylla'
#  'Quercus_Semecarpifolia' 'Quercus_Shumardii' 'Quercus_Texana'
#  'Quercus_Variabilis' 'Rhododendron_x_Russellianum' 'Tilia_Platyphyllos'
#  'Tilia_Tomentosa' 'Viburnum_Tinus']
#
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 327, in _score
#     return self._sign * self._score_func(y, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 2635, in log_loss
#     raise ValueError(
# ValueError: y_true and y_pred contain different number of classes 39, 99. Please provide the true labels explicitly through the labels argument. Classes found in y_true: ['Acer_Mono' 'Acer_Pictum' 'Alnus_Cordata' 'Alnus_Rubra'
#  'Alnus_Sieboldiana' 'Betula_Austrosinensis' 'Betula_Pendula'
#  'Eucalyptus_Glaucescens' 'Fagus_Sylvatica' 'Ginkgo_Biloba'
#  'Ilex_Aquifolium' 'Liquidambar_Styraciflua' 'Liriodendron_Tulipifera'
#  'Populus_Nigra' 'Prunus_Avium' 'Prunus_X_Shmittii' 'Quercus_Alnifolia'
#  'Quercus_Brantii' 'Quercus_Castaneifolia' 'Quercus_Chrysolepis'
#  'Quercus_Coccifera' 'Quercus_Crassipes' 'Quercus_Ellipsoidalis'
#  'Quercus_Imbricaria' 'Quercus_Kewensis' 'Quercus_Nigra'
#  'Quercus_Palustris' 'Quercus_Phellos' 'Quercus_Phillyraeoides'
#  'Quercus_Pontica' 'Quercus_Pubescens' 'Quercus_Pyrenaica'
#  'Quercus_Semecarpifolia' 'Quercus_Suber' 'Quercus_Texana'
#  'Quercus_x_Turneri' 'Tilia_Platyphyllos' 'Ulmus_Bergmanniana'
#  'Viburnum_Tinus']
#
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 327, in _score
#     return self._sign * self._score_func(y, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 2635, in log_loss
#     raise ValueError(
# ValueError: y_true and y_pred contain different number of classes 41, 99. Please provide the true labels explicitly through the labels argument. Classes found in y_true: ['Acer_Mono' 'Acer_Opalus' 'Acer_Pictum' 'Acer_Rubrum' 'Acer_Rufinerve'
#  'Alnus_Cordata' 'Alnus_Rubra' 'Alnus_Sieboldiana' 'Arundinaria_Simonii'
#  'Betula_Austrosinensis' 'Castanea_Sativa' 'Cornus_Controversa'
#  'Cornus_Macrophylla' 'Cotinus_Coggygria' 'Eucalyptus_Urnigera'
#  'Lithocarpus_Edulis' 'Phildelphus' 'Populus_Nigra' 'Prunus_Avium'
#  'Prunus_X_Shmittii' 'Quercus_Afares' 'Quercus_Alnifolia'
#  'Quercus_Canariensis' 'Quercus_Cerris' 'Quercus_Coccifera'
#  'Quercus_Coccinea' 'Quercus_Dolicholepis' 'Quercus_Kewensis'
#  'Quercus_Nigra' 'Quercus_Palustris' 'Quercus_Phellos' 'Quercus_Pubescens'
#  'Quercus_Pyrenaica' 'Quercus_Rubra' 'Quercus_Suber' 'Quercus_Trojana'
#  'Quercus_x_Hispanica' 'Salix_Fragilis' 'Salix_Intergra' 'Tilia_Oliveri'
#  'Viburnum_x_Rhytidophylloides']
#
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 327, in _score
#     return self._sign * self._score_func(y, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 2635, in log_loss
#     raise ValueError(
# ValueError: y_true and y_pred contain different number of classes 41, 99. Please provide the true labels explicitly through the labels argument. Classes found in y_true: ['Acer_Capillipes' 'Acer_Circinatum' 'Acer_Opalus' 'Acer_Palmatum'
#  'Acer_Rufinerve' 'Alnus_Rubra' 'Alnus_Sieboldiana' 'Callicarpa_Bodinieri'
#  'Castanea_Sativa' 'Cercis_Siliquastrum' 'Cornus_Chinensis'
#  'Cornus_Macrophylla' 'Eucalyptus_Urnigera' 'Fagus_Sylvatica'
#  'Liquidambar_Styraciflua' 'Lithocarpus_Cleistocarpus'
#  'Lithocarpus_Edulis' 'Magnolia_Heptapeta' 'Morus_Nigra' 'Phildelphus'
#  'Quercus_Afares' 'Quercus_Chrysolepis' 'Quercus_Crassipes'
#  'Quercus_Ellipsoidalis' 'Quercus_Greggii' 'Quercus_Hartwissiana'
#  'Quercus_Ilex' 'Quercus_Kewensis' 'Quercus_Nigra' 'Quercus_Rhysophylla'
#  'Quercus_Semecarpifolia' 'Quercus_Texana' 'Quercus_Vulcanica'
#  'Rhododendron_x_Russellianum' 'Sorbus_Aria' 'Tilia_Oliveri'
#  'Tilia_Platyphyllos' 'Tilia_Tomentosa' 'Ulmus_Bergmanniana'
#  'Viburnum_Tinus' 'Zelkova_Serrata']
#
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 327, in _score
#     return self._sign * self._score_func(y, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 2635, in log_loss
#     raise ValueError(
# ValueError: y_true and y_pred contain different number of classes 37, 99. Please provide the true labels explicitly through the labels argument. Classes found in y_true: ['Acer_Pictum' 'Acer_Platanoids' 'Acer_Rubrum' 'Acer_Saccharinum'
#  'Alnus_Viridis' 'Betula_Austrosinensis' 'Celtis_Koraiensis'
#  'Cytisus_Battandieri' 'Eucalyptus_Neglecta' 'Fagus_Sylvatica'
#  'Ginkgo_Biloba' 'Ilex_Cornuta' 'Magnolia_Heptapeta'
#  'Magnolia_Salicifolia' 'Olea_Europaea' 'Populus_Grandidentata'
#  'Pterocarya_Stenoptera' 'Quercus_Agrifolia' 'Quercus_Brantii'
#  'Quercus_Castaneifolia' 'Quercus_Cerris' 'Quercus_Coccifera'
#  'Quercus_Crassifolia' 'Quercus_Dolicholepis' 'Quercus_Ilex'
#  'Quercus_Infectoria_sub' 'Quercus_Phellos' 'Quercus_Phillyraeoides'
#  'Quercus_Pontica' 'Quercus_Rubra' 'Quercus_Semecarpifolia'
#  'Quercus_Shumardii' 'Quercus_Suber' 'Quercus_x_Hispanica'
#  'Salix_Intergra' 'Ulmus_Bergmanniana' 'Zelkova_Serrata']
#
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 327, in _score
#     return self._sign * self._score_func(y, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 2635, in log_loss
#     raise ValueError(
# ValueError: y_true and y_pred contain different number of classes 37, 99. Please provide the true labels explicitly through the labels argument. Classes found in y_true: ['Acer_Circinatum' 'Acer_Mono' 'Acer_Opalus' 'Acer_Platanoids'
#  'Acer_Rubrum' 'Acer_Rufinerve' 'Alnus_Maximowiczii' 'Alnus_Viridis'
#  'Callicarpa_Bodinieri' 'Cercis_Siliquastrum' 'Cornus_Chinensis'
#  'Cornus_Controversa' 'Cornus_Macrophylla' 'Crataegus_Monogyna'
#  'Liriodendron_Tulipifera' 'Lithocarpus_Cleistocarpus'
#  'Lithocarpus_Edulis' 'Morus_Nigra' 'Populus_Adenopoda'
#  'Populus_Grandidentata' 'Prunus_Avium' 'Pterocarya_Stenoptera'
#  'Quercus_Afares' 'Quercus_Brantii' 'Quercus_Cerris' 'Quercus_Coccifera'
#  'Quercus_Coccinea' 'Quercus_Dolicholepis' 'Quercus_Greggii'
#  'Quercus_Infectoria_sub' 'Quercus_Palustris' 'Quercus_Pubescens'
#  'Quercus_Pyrenaica' 'Quercus_Suber' 'Quercus_Vulcanica'
#  'Quercus_x_Turneri' 'Rhododendron_x_Russellianum']
#
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 327, in _score
#     return self._sign * self._score_func(y, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 2635, in log_loss
#     raise ValueError(
# ValueError: y_true and y_pred contain different number of classes 41, 99. Please provide the true labels explicitly through the labels argument. Classes found in y_true: ['Acer_Capillipes' 'Acer_Palmatum' 'Acer_Rubrum' 'Alnus_Maximowiczii'
#  'Alnus_Rubra' 'Alnus_Viridis' 'Arundinaria_Simonii' 'Betula_Pendula'
#  'Callicarpa_Bodinieri' 'Cornus_Chinensis' 'Cornus_Controversa'
#  'Cotinus_Coggygria' 'Crataegus_Monogyna' 'Cytisus_Battandieri'
#  'Ginkgo_Biloba' 'Lithocarpus_Cleistocarpus' 'Lithocarpus_Edulis'
#  'Magnolia_Heptapeta' 'Magnolia_Salicifolia' 'Olea_Europaea'
#  'Populus_Adenopoda' 'Populus_Nigra' 'Quercus_Agrifolia'
#  'Quercus_Canariensis' 'Quercus_Castaneifolia' 'Quercus_Chrysolepis'
#  'Quercus_Coccinea' 'Quercus_Crassipes' 'Quercus_Ellipsoidalis'
#  'Quercus_Hartwissiana' 'Quercus_Infectoria_sub' 'Quercus_Pubescens'
#  'Quercus_Rhysophylla' 'Quercus_Rubra' 'Quercus_Shumardii'
#  'Quercus_Trojana' 'Quercus_Variabilis' 'Quercus_x_Turneri'
#  'Salix_Fragilis' 'Sorbus_Aria' 'Tilia_Platyphyllos']
#
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 327, in _score
#     return self._sign * self._score_func(y, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 2635, in log_loss
#     raise ValueError(
# ValueError: y_true and y_pred contain different number of classes 39, 99. Please provide the true labels explicitly through the labels argument. Classes found in y_true: ['Acer_Capillipes' 'Acer_Circinatum' 'Acer_Opalus' 'Acer_Palmatum'
#  'Acer_Platanoids' 'Alnus_Rubra' 'Alnus_Sieboldiana' 'Alnus_Viridis'
#  'Arundinaria_Simonii' 'Betula_Austrosinensis' 'Betula_Pendula'
#  'Castanea_Sativa' 'Cercis_Siliquastrum' 'Cotinus_Coggygria'
#  'Eucalyptus_Glaucescens' 'Eucalyptus_Urnigera' 'Fagus_Sylvatica'
#  'Lithocarpus_Edulis' 'Prunus_X_Shmittii' 'Quercus_Afares'
#  'Quercus_Chrysolepis' 'Quercus_Crassifolia' 'Quercus_Dolicholepis'
#  'Quercus_Greggii' 'Quercus_Hartwissiana' 'Quercus_Palustris'
#  'Quercus_Phellos' 'Quercus_Rhysophylla' 'Quercus_Rubra'
#  'Quercus_Semecarpifolia' 'Quercus_Suber' 'Quercus_Variabilis'
#  'Quercus_x_Hispanica' 'Sorbus_Aria' 'Tilia_Oliveri' 'Tilia_Platyphyllos'
#  'Tilia_Tomentosa' 'Ulmus_Bergmanniana' 'Viburnum_x_Rhytidophylloides']
#
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 327, in _score
#     return self._sign * self._score_func(y, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 2635, in log_loss
#     raise ValueError(
# ValueError: y_true and y_pred contain different number of classes 43, 99. Please provide the true labels explicitly through the labels argument. Classes found in y_true: ['Acer_Circinatum' 'Acer_Mono' 'Acer_Rufinerve' 'Acer_Saccharinum'
#  'Alnus_Maximowiczii' 'Alnus_Viridis' 'Castanea_Sativa'
#  'Celtis_Koraiensis' 'Cornus_Chinensis' 'Crataegus_Monogyna'
# ...
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 327, in _score
#     return self._sign * self._score_func(y, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 2635, in log_loss
#     raise ValueError(
# ValueError: y_true and y_pred contain different number of classes 41, 99. Please provide the true labels explicitly through the labels argument. Classes found in y_true: ['Acer_Capillipes' 'Acer_Palmatum' 'Acer_Rubrum' 'Alnus_Maximowiczii'
#  'Alnus_Rubra' 'Alnus_Viridis' 'Arundinaria_Simonii' 'Betula_Pendula'
#  'Callicarpa_Bodinieri' 'Cornus_Chinensis' 'Cornus_Controversa'
#  'Cotinus_Coggygria' 'Crataegus_Monogyna' 'Cytisus_Battandieri'
#  'Ginkgo_Biloba' 'Lithocarpus_Cleistocarpus' 'Lithocarpus_Edulis'
#  'Magnolia_Heptapeta' 'Magnolia_Salicifolia' 'Olea_Europaea'
#  'Populus_Adenopoda' 'Populus_Nigra' 'Quercus_Agrifolia'
#  'Quercus_Canariensis' 'Quercus_Castaneifolia' 'Quercus_Chrysolepis'
#  'Quercus_Coccinea' 'Quercus_Crassipes' 'Quercus_Ellipsoidalis'
#  'Quercus_Hartwissiana' 'Quercus_Infectoria_sub' 'Quercus_Pubescens'
#  'Quercus_Rhysophylla' 'Quercus_Rubra' 'Quercus_Shumardii'
#  'Quercus_Trojana' 'Quercus_Variabilis' 'Quercus_x_Turneri'
#  'Salix_Fragilis' 'Sorbus_Aria' 'Tilia_Platyphyllos']
#
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 327, in _score
#     return self._sign * self._score_func(y, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 2635, in log_loss
#     raise ValueError(
# ValueError: y_true and y_pred contain different number of classes 39, 99. Please provide the true labels explicitly through the labels argument. Classes found in y_true: ['Acer_Capillipes' 'Acer_Circinatum' 'Acer_Opalus' 'Acer_Palmatum'
#  'Acer_Platanoids' 'Alnus_Rubra' 'Alnus_Sieboldiana' 'Alnus_Viridis'
#  'Arundinaria_Simonii' 'Betula_Austrosinensis' 'Betula_Pendula'
#  'Castanea_Sativa' 'Cercis_Siliquastrum' 'Cotinus_Coggygria'
#  'Eucalyptus_Glaucescens' 'Eucalyptus_Urnigera' 'Fagus_Sylvatica'
#  'Lithocarpus_Edulis' 'Prunus_X_Shmittii' 'Quercus_Afares'
#  'Quercus_Chrysolepis' 'Quercus_Crassifolia' 'Quercus_Dolicholepis'
#  'Quercus_Greggii' 'Quercus_Hartwissiana' 'Quercus_Palustris'
#  'Quercus_Phellos' 'Quercus_Rhysophylla' 'Quercus_Rubra'
#  'Quercus_Semecarpifolia' 'Quercus_Suber' 'Quercus_Variabilis'
#  'Quercus_x_Hispanica' 'Sorbus_Aria' 'Tilia_Oliveri' 'Tilia_Platyphyllos'
#  'Tilia_Tomentosa' 'Ulmus_Bergmanniana' 'Viburnum_x_Rhytidophylloides']
#
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 327, in _score
#     return self._sign * self._score_func(y, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 2635, in log_loss
#     raise ValueError(
# ValueError: y_true and y_pred contain different number of classes 43, 99. Please provide the true labels explicitly through the labels argument. Classes found in y_true: ['Acer_Circinatum' 'Acer_Mono' 'Acer_Rufinerve' 'Acer_Saccharinum'
#  'Alnus_Maximowiczii' 'Alnus_Viridis' 'Castanea_Sativa'
#  'Celtis_Koraiensis' 'Cornus_Chinensis' 'Crataegus_Monogyna'
#  'Fagus_Sylvatica' 'Ilex_Cornuta' 'Olea_Europaea' 'Phildelphus'
#  'Populus_Adenopoda' 'Populus_Nigra' 'Prunus_X_Shmittii'
#  'Pterocarya_Stenoptera' 'Quercus_Agrifolia' 'Quercus_Alnifolia'
#  'Quercus_Brantii' 'Quercus_Canariensis' 'Quercus_Castaneifolia'
#  'Quercus_Chrysolepis' 'Quercus_Coccinea' 'Quercus_Crassipes'
#  'Quercus_Infectoria_sub' 'Quercus_Kewensis' 'Quercus_Nigra'
#  'Quercus_Phillyraeoides' 'Quercus_Pontica' 'Quercus_Rhysophylla'
#  'Quercus_Texana' 'Quercus_Trojana' 'Quercus_Variabilis'
#  'Quercus_Vulcanica' 'Quercus_x_Turneri' 'Rhododendron_x_Russellianum'
#  'Salix_Intergra' 'Sorbus_Aria' 'Tilia_Oliveri'
#  'Viburnum_x_Rhytidophylloides' 'Zelkova_Serrata']
#
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 327, in _score
#     return self._sign * self._score_func(y, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 2635, in log_loss
#     raise ValueError(
# ValueError: y_true and y_pred contain different number of classes 42, 99. Please provide the true labels explicitly through the labels argument. Classes found in y_true: ['Acer_Opalus' 'Acer_Palmatum' 'Acer_Pictum' 'Acer_Rubrum'
#  'Acer_Saccharinum' 'Alnus_Cordata' 'Alnus_Maximowiczii' 'Alnus_Rubra'
#  'Arundinaria_Simonii' 'Betula_Austrosinensis' 'Castanea_Sativa'
#  'Celtis_Koraiensis' 'Cornus_Controversa' 'Eucalyptus_Glaucescens'
#  'Eucalyptus_Neglecta' 'Ginkgo_Biloba' 'Ilex_Aquifolium'
#  'Liquidambar_Styraciflua' 'Liriodendron_Tulipifera'
#  'Lithocarpus_Cleistocarpus' 'Lithocarpus_Edulis' 'Magnolia_Heptapeta'
#  'Magnolia_Salicifolia' 'Morus_Nigra' 'Olea_Europaea' 'Quercus_Cerris'
#  'Quercus_Coccifera' 'Quercus_Ellipsoidalis' 'Quercus_Hartwissiana'
#  'Quercus_Infectoria_sub' 'Quercus_Pontica' 'Quercus_Pyrenaica'
#  'Quercus_Rhysophylla' 'Quercus_Suber' 'Quercus_Variabilis'
#  'Quercus_x_Turneri' 'Rhododendron_x_Russellianum' 'Salix_Fragilis'
#  'Salix_Intergra' 'Sorbus_Aria' 'Tilia_Oliveri' 'Viburnum_Tinus']
#
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 327, in _score
#     return self._sign * self._score_func(y, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 2635, in log_loss
#     raise ValueError(
# ValueError: y_true and y_pred contain different number of classes 36, 99. Please provide the true labels explicitly through the labels argument. Classes found in y_true: ['Acer_Circinatum' 'Acer_Palmatum' 'Acer_Rufinerve' 'Alnus_Maximowiczii'
#  'Betula_Pendula' 'Callicarpa_Bodinieri' 'Celtis_Koraiensis'
#  'Cornus_Macrophylla' 'Cotinus_Coggygria' 'Cytisus_Battandieri'
#  'Eucalyptus_Neglecta' 'Eucalyptus_Urnigera' 'Ilex_Aquifolium'
#  'Magnolia_Heptapeta' 'Olea_Europaea' 'Populus_Nigra'
#  'Pterocarya_Stenoptera' 'Quercus_Agrifolia' 'Quercus_Canariensis'
#  'Quercus_Cerris' 'Quercus_Coccifera' 'Quercus_Crassifolia'
#  'Quercus_Crassipes' 'Quercus_Ilex' 'Quercus_Imbricaria'
#  'Quercus_Kewensis' 'Quercus_Pontica' 'Quercus_Rhysophylla'
#  'Quercus_Semecarpifolia' 'Quercus_Shumardii' 'Quercus_Texana'
#  'Quercus_Variabilis' 'Rhododendron_x_Russellianum' 'Tilia_Platyphyllos'
#  'Tilia_Tomentosa' 'Viburnum_Tinus']
#
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 327, in _score
#     return self._sign * self._score_func(y, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 2635, in log_loss
#     raise ValueError(
# ValueError: y_true and y_pred contain different number of classes 39, 99. Please provide the true labels explicitly through the labels argument. Classes found in y_true: ['Acer_Mono' 'Acer_Pictum' 'Alnus_Cordata' 'Alnus_Rubra'
#  'Alnus_Sieboldiana' 'Betula_Austrosinensis' 'Betula_Pendula'
#  'Eucalyptus_Glaucescens' 'Fagus_Sylvatica' 'Ginkgo_Biloba'
#  'Ilex_Aquifolium' 'Liquidambar_Styraciflua' 'Liriodendron_Tulipifera'
#  'Populus_Nigra' 'Prunus_Avium' 'Prunus_X_Shmittii' 'Quercus_Alnifolia'
#  'Quercus_Brantii' 'Quercus_Castaneifolia' 'Quercus_Chrysolepis'
#  'Quercus_Coccifera' 'Quercus_Crassipes' 'Quercus_Ellipsoidalis'
#  'Quercus_Imbricaria' 'Quercus_Kewensis' 'Quercus_Nigra'
#  'Quercus_Palustris' 'Quercus_Phellos' 'Quercus_Phillyraeoides'
#  'Quercus_Pontica' 'Quercus_Pubescens' 'Quercus_Pyrenaica'
#  'Quercus_Semecarpifolia' 'Quercus_Suber' 'Quercus_Texana'
#  'Quercus_x_Turneri' 'Tilia_Platyphyllos' 'Ulmus_Bergmanniana'
#  'Viburnum_Tinus']
#
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 327, in _score
#     return self._sign * self._score_func(y, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 2635, in log_loss
#     raise ValueError(
# ValueError: y_true and y_pred contain different number of classes 41, 99. Please provide the true labels explicitly through the labels argument. Classes found in y_true: ['Acer_Mono' 'Acer_Opalus' 'Acer_Pictum' 'Acer_Rubrum' 'Acer_Rufinerve'
#  'Alnus_Cordata' 'Alnus_Rubra' 'Alnus_Sieboldiana' 'Arundinaria_Simonii'
#  'Betula_Austrosinensis' 'Castanea_Sativa' 'Cornus_Controversa'
#  'Cornus_Macrophylla' 'Cotinus_Coggygria' 'Eucalyptus_Urnigera'
#  'Lithocarpus_Edulis' 'Phildelphus' 'Populus_Nigra' 'Prunus_Avium'
#  'Prunus_X_Shmittii' 'Quercus_Afares' 'Quercus_Alnifolia'
#  'Quercus_Canariensis' 'Quercus_Cerris' 'Quercus_Coccifera'
#  'Quercus_Coccinea' 'Quercus_Dolicholepis' 'Quercus_Kewensis'
#  'Quercus_Nigra' 'Quercus_Palustris' 'Quercus_Phellos' 'Quercus_Pubescens'
#  'Quercus_Pyrenaica' 'Quercus_Rubra' 'Quercus_Suber' 'Quercus_Trojana'
#  'Quercus_x_Hispanica' 'Salix_Fragilis' 'Salix_Intergra' 'Tilia_Oliveri'
#  'Viburnum_x_Rhytidophylloides']
#
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 327, in _score
#     return self._sign * self._score_func(y, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py", line 2635, in log_loss
#     raise ValueError(
# ValueError: y_true and y_pred contain different number of classes 41, 99. Please provide the true labels explicitly through the labels argument. Classes found in y_true: ['Acer_Capillipes' 'Acer_Circinatum' 'Acer_Opalus' 'Acer_Palmatum'
#  'Acer_Rufinerve' 'Alnus_Rubra' 'Alnus_Sieboldiana' 'Callicarpa_Bodinieri'
#  'Castanea_Sativa' 'Cercis_Siliquastrum' 'Cornus_Chinensis'
#  'Cornus_Macrophylla' 'Eucalyptus_Urnigera' 'Fagus_Sylvatica'
#  'Liquidambar_Styraciflua' 'Lithocarpus_Cleistocarpus'
#  'Lithocarpus_Edulis' 'Magnolia_Heptapeta' 'Morus_Nigra' 'Phildelphus'
#  'Quercus_Afares' 'Quercus_Chrysolepis' 'Quercus_Crassipes'
#  'Quercus_Ellipsoidalis' 'Quercus_Greggii' 'Quercus_Hartwissiana'
#  'Quercus_Ilex' 'Quercus_Kewensis' 'Quercus_Nigra' 'Quercus_Rhysophylla'
#  'Quercus_Semecarpifolia' 'Quercus_Texana' 'Quercus_Vulcanica'
#  'Rhododendron_x_Russellianum' 'Sorbus_Aria' 'Tilia_Oliveri'
#  'Tilia_Platyphyllos' 'Tilia_Tomentosa' 'Ulmus_Bergmanniana'
#  'Viburnum_Tinus' 'Zelkova_Serrata']
#
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_search.py:952: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan]
#   warnings.warn(
# Best parameter: {'C': 1, 'tol': 0.001}
# Best cross-validation neg_log_loss score: nan
#
# Best estimator:
# LogisticRegression(C=1, max_iter=10000, multi_class='multinomial',
#                    random_state=42, tol=0.001)

# %%
scaler = StandardScaler().fit(X_val)
X_val_scaled = scaler.transform(X_val)

print ('ML Model: Logistic Regression')
# Accuracy
train_predictions = grid_search.predict(X_val_scaled)
acc = accuracy_score(y_val, train_predictions)
print ('Accuracy: {:.4%}'.format(acc))

#Precision
precision = precision_score(y_val, train_predictions, average='weighted')
print('Precision: {:.4%}'.format(precision))

#Recall
recall = recall_score(y_val, train_predictions,average='weighted')
print('Recall: {:.4%}'.format(recall))

# Logloss
train_predictions_p = grid_search.predict_proba(X_val_scaled)
ll = log_loss(y_val, train_predictions_p)
print ('Log Loss: {:.6}'.format(ll))
# Out:
# ML Model: Logistic Regression
# Accuracy: 98.5577%
# Precision: 99.1186%
# Recall: 98.5577%
# Log Loss: 0.189192

# %% [markdown]
# #### 4.2.4 K-Nearest Neighbours

# %%
clf = KNeighborsClassifier(3)  # Instantiate a classifier
clf.fit(X_train, y_train) # Fit this classifier to the data
print ('ML Model: ', clf.__class__.__name__)

# Cross-validation
scores = cross_val_score(KNeighborsClassifier(3), X_train.values, y_train, cv=kf_split)
#print 'Mean Cross-validation scores: {}'.format(np.mean(scores))

train_predictions = clf.predict(X_val)
#Accuracy
acc = accuracy_score(y_val, train_predictions)
print ('Accuracy: {:.4%}'.format(acc))

#Precision
precision = precision_score(y_val, train_predictions, average='weighted')
print('Precision: {:.4%}'.format(precision))

#Recall
recall = recall_score(y_val, train_predictions,average='weighted')
print('Recall: {:.4%}'.format(recall))

#Log loss
train_predictions = clf.predict_proba(X_val)
ll = log_loss(y_val, train_predictions)
print ('Log Loss: {:.6}'.format(ll))
# Out:
# ML Model:  KNeighborsClassifier
# Accuracy: 84.6154%
# Precision: 85.0240%
# Recall: 84.6154%
# Log Loss: 2.53984
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
